# %%
import pandas as pd

# %%
path = './permutation_importance.tsv'

df = pd.read_csv(path, sep='\t')

# %%
df
# Out:
#                                                feature  \
# 0                                 RAW_1_stats_cv_whole
# 1    RAW_10_percentage_of_reoccurring_datapoints_to...
# 2    RAW_10_percentage_of_reoccurring_values_to_all...
# 3                                RAW_1_stats_std_whole
# 4    RAW_10_percentage_of_reoccurring_values_to_all...
# ..                                                 ...
# 850  RAW_10_change_quantiles_f_agg_var_isabs_True_q...
# 851  RAW_10_agg_linear_trend_attr_rvalue_chunk_len_...
# 852             RAW_10_first_location_of_maximum_whole
# 853                          RAW_12_rpt_cost_rank_diff
# 854                                RAW_11_param_4_diff
#
#      permutation_importance_mean  permutation_importance_std
# 0                       0.021545                    0.002249
# 1                       0.016222                    0.009609
# 2                       0.011942                    0.007072
# 3                       0.003972                    0.001954
# 4                       0.003296                    0.002501
# ..                           ...                         ...
# 850                    -0.000193                    0.000503
# 851                    -0.000204                    0.000530
# 852                    -0.000321                    0.000717
# 853                    -0.000323                    0.000578
# 854                    -0.000398                    0.000885
#
# [855 rows x 3 columns]

# %%
df_filtered = df[df['permutation_importance_mean'] > 0.0002]

# %%
df_filtered
# Out:
#                                               feature  \
# 0                                RAW_1_stats_cv_whole
# 1   RAW_10_percentage_of_reoccurring_datapoints_to...
# 2   RAW_10_percentage_of_reoccurring_values_to_all...
# 3                               RAW_1_stats_std_whole
# 4   RAW_10_percentage_of_reoccurring_values_to_all...
# 5                               RAW_2_bartlett_pvalue
# 6                           RAW_10_quantile_0_4_whole
# 7   RAW_10_fft_coefficient_attr_imag_coeff_1_ratio...
# 8                           RAW_8_sample_entropy_left
# 9   RAW_10_fft_coefficient_attr_imag_coeff_1_ratio...
# 10                                      RAW_2_ks_stat
# 11                                RAW_2_bartlett_stat
# 12  RAW_10_percentage_of_reoccurring_values_to_all...
# 13                                      RAW_2_ad_stat
# 14  RAW_10_ratio_value_number_to_time_series_lengt...
# 15                              RAW_1_stats_kurt_left
# 16  RAW_10_ratio_value_number_to_time_series_lengt...
# 17                                    RAW_2_ks_pvalue
# 18  RAW_10_percentage_of_reoccurring_datapoints_to...
# 19                                  RAW_2_levene_stat
# 20     RAW_10_fft_coefficient_attr_imag_coeff_1_whole
# 21               RAW_3_cumsum_max_ratio_to_whole_left
# 22                          RAW_2_shapiro_pvalue_left
# 23                             RAW_1_stats_mean_whole
# 24                    RAW_13_robust_quartile_cv_whole
# 25  RAW_10_agg_linear_trend_attr_rvalue_chunk_len_...
# 26                           RAW_4_autocorr_lag1_diff
# 27                         RAW_13_robust_log_cv_ratio
# 28  RAW_10_agg_linear_trend_attr_rvalue_chunk_len_...
# 29  RAW_10_ratio_value_number_to_time_series_lengt...
# 30                          RAW_10_quantile_0_4_right
# 31              RAW_10_linear_trend_attr_rvalue_ratio
# 32                       RAW_12_rpt_cost_cosine_whole
# 33                         RAW_13_robust_mad_cv_whole
# 34                                RAW_2_levene_pvalue
# 35                         RAW_13_robust_iqr_cv_whole
# 36  RAW_10_change_quantiles_f_agg_var_isabs_True_q...
# 37                              RAW_1_stats_min_whole
# 38                             RAW_1_stats_kurt_whole
# 39                           RAW_1_stats_median_ratio
# 40                             RAW_1_stats_mean_right
# 41  RAW_10_percentage_of_reoccurring_values_to_all...
# 42                   RAW_7_rolling_std_w50_mean_whole
# 43  RAW_10_change_quantiles_f_agg_var_isabs_False_...
# 44           RAW_10_linear_trend_attr_intercept_ratio
# 45                          RAW_4_autocorr_lag1_ratio
# 46            RAW_10_ar_coefficient_coeff_2_k_10_left
# 47            RAW_10_quantile_0_6_ratio_to_whole_left
# 48  RAW_10_agg_linear_trend_attr_rvalue_chunk_len_...
# 49  RAW_10_change_quantiles_f_agg_var_isabs_False_...
# 50  RAW_10_percentage_of_reoccurring_datapoints_to...
# 51                           RAW_1_stats_median_whole
# 52  RAW_10_change_quantiles_f_agg_var_isabs_False_...
# 53                        RAW_8_spectral_entropy_left
# 54                            RAW_8_perm_entropy_left
# 55                              RAW_5_max_power_whole
# 56                               RAW_2_jb_pvalue_left
# 57                         RAW_8_sample_entropy_whole
#
#     permutation_importance_mean  permutation_importance_std
# 0                      0.021545                    0.002249
# 1                      0.016222                    0.009609
# 2                      0.011942                    0.007072
# 3                      0.003972                    0.001954
# 4                      0.003296                    0.002501
# 5                      0.003199                    0.003452
# 6                      0.003148                    0.001908
# 7                      0.003139                    0.000835
# 8                      0.003008                    0.000987
# 9                      0.002984                    0.001009
# 10                     0.002636                    0.001641
# 11                     0.002413                    0.002352
# 12                     0.002322                    0.002018
# 13                     0.002166                    0.002783
# 14                     0.001617                    0.002520
# 15                     0.001490                    0.001027
# 16                     0.001430                    0.000896
# 17                     0.001325                    0.003158
# 18                     0.001205                    0.000542
# 19                     0.001119                    0.000740
# 20                     0.001104                    0.000752
# 21                     0.001073                    0.000419
# 22                     0.000926                    0.002040
# 23                     0.000910                    0.001044
# 24                     0.000899                    0.000411
# 25                     0.000863                    0.000224
# 26                     0.000814                    0.000463
# 27                     0.000771                    0.000331
# 28                     0.000768                    0.000523
# 29                     0.000768                    0.000545
# 30                     0.000731                    0.000624
# 31                     0.000730                    0.000212
# 32                     0.000717                    0.000631
# 33                     0.000690                    0.000415
# 34                     0.000680                    0.001439
# 35                     0.000678                    0.000358
# 36                     0.000672                    0.000654
# 37                     0.000655                    0.000893
# 38                     0.000635                    0.000534
# 39                     0.000612                    0.000499
# 40                     0.000559                    0.000404
# 41                     0.000557                    0.001207
# 42                     0.000556                    0.000291
# 43                     0.000535                    0.000525
# 44                     0.000524                    0.000488
# 45                     0.000521                    0.000383
# 46                     0.000478                    0.000546
# 47                     0.000476                    0.000582
# 48                     0.000474                    0.000288
# 49                     0.000471                    0.000327
# 50                     0.000456                    0.000610
# 51                     0.000453                    0.000410
# 52                     0.000442                    0.000229
# 53                     0.000431                    0.000228
# 54                     0.000412                    0.000425
# 55                     0.000411                    0.000256
# 56                     0.000405                    0.000558
# 57                     0.000401                    0.000223

# %%
df_feature_list = df_filtered.sort_values(by='permutation_importance_mean', ascending=False)['feature'].tolist()

# %%
df_feature_list
# Out:
# ['RAW_1_stats_cv_whole',
#  'RAW_10_percentage_of_reoccurring_datapoints_to_all_datapoints_contribution_left',
#  'RAW_10_percentage_of_reoccurring_values_to_all_values_contribution_left',
#  'RAW_1_stats_std_whole',
#  'RAW_10_percentage_of_reoccurring_values_to_all_values_ratio_to_whole_left',
#  'RAW_2_bartlett_pvalue',
#  'RAW_10_quantile_0_4_whole',
#  'RAW_10_fft_coefficient_attr_imag_coeff_1_ratio_to_whole_right',
#  'RAW_8_sample_entropy_left',
#  'RAW_10_fft_coefficient_attr_imag_coeff_1_ratio_to_whole_left',
#  'RAW_2_ks_stat',
#  'RAW_2_bartlett_stat',
#  'RAW_10_percentage_of_reoccurring_values_to_all_values_ratio',
#  'RAW_2_ad_stat',
#  'RAW_10_ratio_value_number_to_time_series_length_diff',
#  'RAW_1_stats_kurt_left',
#  'RAW_10_ratio_value_number_to_time_series_length_ratio_to_whole_left',
#  'RAW_2_ks_pvalue',
#  'RAW_10_percentage_of_reoccurring_datapoints_to_all_datapoints_ratio_to_whole_right',
#  'RAW_2_levene_stat',
#  'RAW_10_fft_coefficient_attr_imag_coeff_1_whole',
#  'RAW_3_cumsum_max_ratio_to_whole_left',
#  'RAW_2_shapiro_pvalue_left',
#  'RAW_1_stats_mean_whole',
#  'RAW_13_robust_quartile_cv_whole',
#  'RAW_10_agg_linear_trend_attr_rvalue_chunk_len_50_f_agg_max_ratio_to_whole_left',
#  'RAW_4_autocorr_lag1_diff',
#  'RAW_13_robust_log_cv_ratio',
#  'RAW_10_agg_linear_trend_attr_rvalue_chunk_len_50_f_agg_mean_diff',
#  'RAW_10_ratio_value_number_to_time_series_length_whole',
#  'RAW_10_quantile_0_4_right',
#  'RAW_10_linear_trend_attr_rvalue_ratio',
#  'RAW_12_rpt_cost_cosine_whole',
#  'RAW_13_robust_mad_cv_whole',
#  'RAW_2_levene_pvalue',
#  'RAW_13_robust_iqr_cv_whole',
#  'RAW_10_change_quantiles_f_agg_var_isabs_True_qh_0_6_ql_0_2_whole',
#  'RAW_1_stats_min_whole',
#  'RAW_1_stats_kurt_whole',
#  'RAW_1_stats_median_ratio',
#  'RAW_1_stats_mean_right',
#  'RAW_10_percentage_of_reoccurring_values_to_all_values_diff',
#  'RAW_7_rolling_std_w50_mean_whole',
#  'RAW_10_change_quantiles_f_agg_var_isabs_False_qh_0_8_ql_0_4_whole',
#  'RAW_10_linear_trend_attr_intercept_ratio',
#  'RAW_4_autocorr_lag1_ratio',
#  'RAW_10_ar_coefficient_coeff_2_k_10_left',
#  'RAW_10_quantile_0_6_ratio_to_whole_left',
#  'RAW_10_agg_linear_trend_attr_rvalue_chunk_len_5_f_agg_max_right',
#  'RAW_10_change_quantiles_f_agg_var_isabs_False_qh_0_8_ql_0_0_whole',
#  'RAW_10_percentage_of_reoccurring_datapoints_to_all_datapoints_ratio_to_whole_left',
#  'RAW_1_stats_median_whole',
#  'RAW_10_change_quantiles_f_agg_var_isabs_False_qh_0_8_ql_0_0_right',
#  'RAW_8_spectral_entropy_left',
#  'RAW_8_perm_entropy_left',
#  'RAW_5_max_power_whole',
#  'RAW_2_jb_pvalue_left',
#  'RAW_8_sample_entropy_whole']
