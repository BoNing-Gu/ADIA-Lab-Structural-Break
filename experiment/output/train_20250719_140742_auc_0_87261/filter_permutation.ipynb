# %%
import pandas as pd

# %%
path = './permutation_importance.tsv'

df = pd.read_csv(path, sep='\t')

# %%
df
# Out:
#                                                feature  \
# 0                                 RAW_1_stats_cv_whole
# 1    RAW_10_percentage_of_reoccurring_datapoints_to...
# 2    RAW_10_percentage_of_reoccurring_values_to_all...
# 3                                RAW_1_stats_std_whole
# 4    RAW_10_percentage_of_reoccurring_values_to_all...
# ..                                                 ...
# 850  RAW_10_change_quantiles_f_agg_var_isabs_True_q...
# 851  RAW_10_agg_linear_trend_attr_rvalue_chunk_len_...
# 852             RAW_10_first_location_of_maximum_whole
# 853                          RAW_12_rpt_cost_rank_diff
# 854                                RAW_11_param_4_diff
#
#      permutation_importance_mean  permutation_importance_std
# 0                       0.021545                    0.002249
# 1                       0.016222                    0.009609
# 2                       0.011942                    0.007072
# 3                       0.003972                    0.001954
# 4                       0.003296                    0.002501
# ..                           ...                         ...
# 850                    -0.000193                    0.000503
# 851                    -0.000204                    0.000530
# 852                    -0.000321                    0.000717
# 853                    -0.000323                    0.000578
# 854                    -0.000398                    0.000885
#
# [855 rows x 3 columns]

# %%
df_filtered = df[df['permutation_importance_mean'] > 0.0002]

# %%
df_filtered
# Out:
#                                                feature  \
# 0                                 RAW_1_stats_cv_whole
# 1    RAW_10_percentage_of_reoccurring_datapoints_to...
# 2    RAW_10_percentage_of_reoccurring_values_to_all...
# 3                                RAW_1_stats_std_whole
# 4    RAW_10_percentage_of_reoccurring_values_to_all...
# ..                                                 ...
# 112  RAW_10_ratio_value_number_to_time_series_lengt...
# 113                               RAW_1_stats_min_diff
# 114          RAW_10_partial_autocorrelation_lag_2_left
# 115                                RAW_11_param_5_diff
# 116               RAW_10_linear_trend_attr_rvalue_diff
#
#      permutation_importance_mean  permutation_importance_std
# 0                       0.021545                    0.002249
# 1                       0.016222                    0.009609
# 2                       0.011942                    0.007072
# 3                       0.003972                    0.001954
# 4                       0.003296                    0.002501
# ..                           ...                         ...
# 112                     0.000209                    0.000282
# 113                     0.000206                    0.000262
# 114                     0.000206                    0.000153
# 115                     0.000205                    0.000297
# 116                     0.000205                    0.000292
#
# [117 rows x 3 columns]

# %%
df_feature_list = df_filtered.sort_values(by='permutation_importance_mean', ascending=False)['feature'].tolist()

# %%
df_feature_list
# Out:
# ['RAW_1_stats_cv_whole',
#  'RAW_10_percentage_of_reoccurring_datapoints_to_all_datapoints_contribution_left',
#  'RAW_10_percentage_of_reoccurring_values_to_all_values_contribution_left',
#  'RAW_1_stats_std_whole',
#  'RAW_10_percentage_of_reoccurring_values_to_all_values_ratio_to_whole_left',
#  'RAW_2_bartlett_pvalue',
#  'RAW_10_quantile_0_4_whole',
#  'RAW_10_fft_coefficient_attr_imag_coeff_1_ratio_to_whole_right',
#  'RAW_8_sample_entropy_left',
#  'RAW_10_fft_coefficient_attr_imag_coeff_1_ratio_to_whole_left',
#  'RAW_2_ks_stat',
#  'RAW_2_bartlett_stat',
#  'RAW_10_percentage_of_reoccurring_values_to_all_values_ratio',
#  'RAW_2_ad_stat',
#  'RAW_10_ratio_value_number_to_time_series_length_diff',
#  'RAW_1_stats_kurt_left',
#  'RAW_10_ratio_value_number_to_time_series_length_ratio_to_whole_left',
#  'RAW_2_ks_pvalue',
#  'RAW_10_percentage_of_reoccurring_datapoints_to_all_datapoints_ratio_to_whole_right',
#  'RAW_2_levene_stat',
#  'RAW_10_fft_coefficient_attr_imag_coeff_1_whole',
#  'RAW_3_cumsum_max_ratio_to_whole_left',
#  'RAW_2_shapiro_pvalue_left',
#  'RAW_1_stats_mean_whole',
#  'RAW_13_robust_quartile_cv_whole',
#  'RAW_10_agg_linear_trend_attr_rvalue_chunk_len_50_f_agg_max_ratio_to_whole_left',
#  'RAW_4_autocorr_lag1_diff',
#  'RAW_13_robust_log_cv_ratio',
#  'RAW_10_agg_linear_trend_attr_rvalue_chunk_len_50_f_agg_mean_diff',
#  'RAW_10_ratio_value_number_to_time_series_length_whole',
#  'RAW_10_quantile_0_4_right',
#  'RAW_10_linear_trend_attr_rvalue_ratio',
#  'RAW_12_rpt_cost_cosine_whole',
#  'RAW_13_robust_mad_cv_whole',
#  'RAW_2_levene_pvalue',
#  'RAW_13_robust_iqr_cv_whole',
#  'RAW_10_change_quantiles_f_agg_var_isabs_True_qh_0_6_ql_0_2_whole',
#  'RAW_1_stats_min_whole',
#  'RAW_1_stats_kurt_whole',
#  'RAW_1_stats_median_ratio',
#  'RAW_1_stats_mean_right',
#  'RAW_10_percentage_of_reoccurring_values_to_all_values_diff',
#  'RAW_7_rolling_std_w50_mean_whole',
#  'RAW_10_change_quantiles_f_agg_var_isabs_False_qh_0_8_ql_0_4_whole',
#  'RAW_10_linear_trend_attr_intercept_ratio',
#  'RAW_4_autocorr_lag1_ratio',
#  'RAW_10_ar_coefficient_coeff_2_k_10_left',
#  'RAW_10_quantile_0_6_ratio_to_whole_left',
#  'RAW_10_agg_linear_trend_attr_rvalue_chunk_len_5_f_agg_max_right',
#  'RAW_10_change_quantiles_f_agg_var_isabs_False_qh_0_8_ql_0_0_whole',
#  'RAW_10_percentage_of_reoccurring_datapoints_to_all_datapoints_ratio_to_whole_left',
#  'RAW_1_stats_median_whole',
#  'RAW_10_change_quantiles_f_agg_var_isabs_False_qh_0_8_ql_0_0_right',
#  'RAW_8_spectral_entropy_left',
#  'RAW_8_perm_entropy_left',
#  'RAW_5_max_power_whole',
#  'RAW_2_jb_pvalue_left',
#  'RAW_8_sample_entropy_whole',
#  'RAW_6_iqr_whole',
#  'RAW_8_sample_entropy_diff',
#  'RAW_13_robust_log_cv_left',
#  'RAW_10_quantile_0_1_ratio',
#  'RAW_11_param_0_whole',
#  'RAW_10_change_quantiles_f_agg_var_isabs_True_qh_1_0_ql_0_4_contribution_left',
#  'RAW_10_linear_trend_attr_intercept_contribution_left',
#  'RAW_1_stats_cv_ratio_to_whole_left',
#  'RAW_10_agg_linear_trend_attr_rvalue_chunk_len_5_f_agg_max_diff',
#  'RAW_10_percentage_of_reoccurring_values_to_all_values_contribution_right',
#  'RAW_12_rpt_cost_rank_left',
#  'RAW_8_cond_entropy_left',
#  'RAW_2_ad_pvalue',
#  'RAW_2_adf_icbest_left',
#  'RAW_10_fft_coefficient_attr_imag_coeff_1_left',
#  'RAW_10_ratio_beyond_r_sigma_1_5_left',
#  'RAW_10_percentage_of_reoccurring_values_to_all_values_right',
#  'RAW_8_svd_entropy_ratio_to_whole_left',
#  'RAW_13_robust_log_cv_diff',
#  'RAW_10_quantile_0_6_whole',
#  'RAW_8_higuchi_fd_ratio_to_whole_left',
#  'RAW_10_ratio_beyond_r_sigma_1_5_whole',
#  'RAW_2_shapiro_pvalue_whole',
#  'RAW_10_ratio_value_number_to_time_series_length_ratio',
#  'RAW_10_agg_linear_trend_attr_rvalue_chunk_len_10_f_agg_max_diff',
#  'RAW_10_ratio_beyond_r_sigma_1_5_diff',
#  'RAW_8_perm_entropy_whole',
#  'RAW_10_change_quantiles_f_agg_var_isabs_False_qh_0_6_ql_0_2_whole',
#  'RAW_2_jb_pvalue_ratio',
#  'RAW_10_fft_coefficient_attr_imag_coeff_2_ratio_to_whole_left',
#  'RAW_13_robust_log_cv_whole',
#  'RAW_10_ar_coefficient_coeff_2_k_10_right',
#  'RAW_10_agg_linear_trend_attr_intercept_chunk_len_50_f_agg_mean_ratio_to_whole_left',
#  'RAW_8_lziv_complexity_right',
#  'RAW_10_partial_autocorrelation_lag_2_whole',
#  'RAW_10_ratio_beyond_r_sigma_1_5_ratio',
#  'RAW_10_linear_trend_attr_rvalue_ratio_to_whole_right',
#  'RAW_10_linear_trend_attr_intercept_ratio_to_whole_left',
#  'RAW_10_quantile_0_4_ratio_to_whole_left',
#  'RAW_11_param_0_ratio_to_whole_right',
#  'RAW_10_percentage_of_reoccurring_datapoints_to_all_datapoints_ratio',
#  'RAW_10_agg_linear_trend_attr_intercept_chunk_len_10_f_agg_max_ratio_to_whole_right',
#  'RAW_1_stats_std_right',
#  'RAW_10_change_quantiles_f_agg_var_isabs_True_qh_0_6_ql_0_4_whole',
#  'RAW_10_quantile_0_6_diff',
#  'RAW_10_agg_linear_trend_attr_rvalue_chunk_len_5_f_agg_max_left',
#  'RAW_10_quantile_0_6_left',
#  'RAW_12_rpt_cost_l1_left',
#  'RAW_1_stats_median_contribution_right',
#  'RAW_13_robust_log_cv_right',
#  'RAW_10_agg_linear_trend_attr_rvalue_chunk_len_50_f_agg_max_ratio',
#  'RAW_8_katz_fd_whole',
#  'RAW_8_approx_entropy_left',
#  'RAW_10_change_quantiles_f_agg_var_isabs_False_qh_0_8_ql_0_4_ratio',
#  'RAW_10_ratio_value_number_to_time_series_length_ratio_to_whole_right',
#  'RAW_1_stats_min_diff',
#  'RAW_10_partial_autocorrelation_lag_2_left',
#  'RAW_11_param_5_diff',
#  'RAW_10_linear_trend_attr_rvalue_diff']
